# %%
from models import *
from sklearn.ensemble import RandomForestRegressor
from keras.models import Sequential
from keras.layers import Dense, LSTM
from keras.losses import mean_squared_error
# Out:
# Using TensorFlow backend.
# return form: y_train,x_train,(y_vali,x_vail),y_test,x_test

# %%
with open('sp500_list.txt','r') as f:
    splist = f.read().splitlines()

# %%
lis_success=[]
lis_fail=[]
result_df = pd.DataFrame({'garch':[],
                          'random forest':[],
                          'RNN':[]})

for ticker in splist[:3]:
    try:
        r2_garch = garch(ticker)
        r2_rf = rf(ticker)
        r2_rnn = rnn(ticker)
        result_df = result_df.append({'garch':r2_garch,'random forest':r2_rf,'RNN':r2_rnn},ignore_index=True)
        lis_success.append(ticker)
    except:
        lis_fail.append(ticker)
# Out:
# Iteration:      5,   Func. Count:     38,   Neg. LLF: 3424.5936300314956
# Iteration:     10,   Func. Count:     72,   Neg. LLF: 3423.209982260805
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 3423.2095279109335
#             Iterations: 12
#             Function evaluations: 85
#             Gradient evaluations: 12
# Epoch 1/10
# 1762/1762 [==============================] - 7s - loss: 4.4194
# Epoch 2/10
#  - ETA: 1s - loss: 1.5278
# Epoch 3/10
# 1762/1762 [==============================] - 4s - loss: 0.8077
# Epoch 4/10
# 1762/1762 [==============================] - 4s - loss: 0.5560
# Epoch 5/10
# 1762/1762 [==============================] - 4s - loss: 0.5449
# Epoch 6/10
# 1762/1762 [==============================] - 4s - loss: 0.4783
# Epoch 7/10
# 1762/1762 [==============================] - 4s - loss: 0.4314
# Epoch 8/10
# 1762/1762 [==============================] - 4s - loss: 0.4079
# Epoch 9/10
# 1762/1762 [==============================] - 5s - loss: 0.4101
# Epoch 10/10
# 1762/1762 [==============================] - 5s - loss: 0.3541
# Iteration:      5,   Func. Count:     38,   Neg. LLF: 3424.5936300314956
# Iteration:     10,   Func. Count:     72,   Neg. LLF: 3423.209982260805
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 3423.2095279109335
#             Iterations: 12
#             Function evaluations: 85
#             Gradient evaluations: 12
# Epoch 1/10
# 1762/1762 [==============================] - 4s - loss: 6.5832
# Epoch 2/10
#  - ETA: 0s - loss: 2.0366
# Epoch 3/10
# 1762/1762 [==============================] - 3s - loss: 1.0986
# Epoch 4/10
# 1762/1762 [==============================] - 4s - loss: 0.8826
# Epoch 5/10
# 1762/1762 [==============================] - 3s - loss: 0.7956
# Epoch 6/10
# 1762/1762 [==============================] - 5s - loss: 0.7130
# Epoch 7/10
# 1762/1762 [==============================] - 5s - loss: 0.7163
# Epoch 8/10
# 1762/1762 [==============================] - 5s - loss: 0.6738
# Epoch 9/10
# 1762/1762 [==============================] - 4s - loss: 0.6699
# Epoch 10/10
# 1762/1762 [==============================] - 5s - loss: 0.6303
# Iteration:      5,   Func. Count:     38,   Neg. LLF: 3424.5936300314956
# Iteration:     10,   Func. Count:     72,   Neg. LLF: 3423.209982260805
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 3423.2095279109335
#             Iterations: 12
#             Function evaluations: 85
#             Gradient evaluations: 12
# Epoch 1/10
# 1762/1762 [==============================] - 6s - loss: 3.6019
# Epoch 2/10
# 1762/1762 [==============================] - 5s - loss: 0.7774
# Epoch 3/10
# 1762/1762 [==============================] - 4s - loss: 0.4242
# Epoch 4/10
# 1762/1762 [==============================] - 4s - loss: 0.3014
# Epoch 5/10
# 1762/1762 [==============================] - 4s - loss: 0.2374
# Epoch 6/10
# 1762/1762 [==============================] - 4s - loss: 0.2422
# Epoch 7/10
# 1650/1762 [===========================>..] - ETA: 0s - loss: 0.2116

# %%
result_df.to_csv('result.csv')
# Out:
# ['ACN', 'ATVI', 'APD']
